# %% [markdown]
# ![image.png](attachment:2ae3a4d3-cd4b-48e5-915d-3a599f592d33.png)

# %%
# 8. Sigmoid probability first
x = 3
b_0 = -3
b_1 = 0.6
e = 2.718281828459045
e_minus = e ** -1

p = round(1/(1+e_minus**(b_0+b_1*x)),5)

print(f'the propablty P in persentage = {p*100} %')
# Out:
# the propablty P in persentage = 23.148 %

# %%
# 8. Sigmoid probability second

x2 = 8
b_0_2 = -3
b_1_2 = 0.6
e = 2.718281828459045
e_minus = e ** -1

p_2 = round(1/(1+e_minus**(b_0_2+b_1_2*x2)),5)

print(f'the propablty P in persentage = {p_2*100} %')
# Out:
# the propablty P in persentage = 85.815 %

# %%
import numpy as py

b_0_3 = -3
b_1_3 = 0.6
p_3 = 0.8

x = (np.log(0.8/(1-0.8))-b_0_3)/b_1_3

print(f"The number of suspicious keywords x is: {round(x,4)}")
# Out:
# The number of suspicious keywords x is: 7.3105
